# %%
using DataFrames
using Gadfly

# %%
# df showing probelms and how many people have solved them. Data from 13/01/2016
df = readtable("/home/dom/Julia/Rosalind/Files/problems.csv")
# Out:
# 105×3 DataFrames.DataFrame
# │ Row │ ID     │ Title                                                         │
# ├─────┼────────┼───────────────────────────────────────────────────────────────┤
# │ 1   │ "DNA"  │ "Counting DNA Nucleotides"                                    │
# │ 2   │ "RNA"  │ "Transcribing DNA into RNA"                                   │
# │ 3   │ "REVC" │ "Complementing a Strand of DNA"                               │
# │ 4   │ "GC"   │ "Computing GC Content"                                        │
# │ 5   │ "HAMM" │ "Counting Point Mutations"                                    │
# │ 6   │ "PROT" │ "Translating RNA into Protein"                                │
# │ 7   │ "FIB"  │ "Rabbits and Recurrence Relations"                            │
# │ 8   │ "IPRB" │ "Mendel's First Law"                                          │
# │ 9   │ "SUBS" │ "Finding a Motif in DNA"                                      │
# ...

# %%
#Graph
plot(y=df[:Solved_By],
Guide.ylabel("Number Solved by"),
Guide.xlabel("Problem level"),
Guide.title("Problem level vs Number Solved by"))
# Out:
# Plot(...)

# %%
using Polynomials    # install with Pkg.add("Polynomials")
x = [1,2,3]          # demo x
y = [10,12,4]        # demo y

polyfit(x,y)
